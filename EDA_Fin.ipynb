# %% [markdown]
# <a href="https://colab.research.google.com/github/hoangson281205/ueh-ktlt-eco/blob/Buoi4/EDA_Fin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Phân tích dữ liệu tài chính
# Notebook này được viết lại theo phong cách tự nhiên hơn, có chú thích tiếng Việt và trình bày rõ ràng các bước EDA.
# Mục tiêu: Hiểu rõ đặc điểm dữ liệu tài chính, kiểm tra phân phối, và trực quan hóa mối quan hệ giữa các biến.

# %% [markdown]
# # Buổi 04: Đầu tư định lượng dùng Pandas

# %%
# --- Phần xử lý và phân tích dữ liệu ---
# !pip install pandas_du_lieu_phan_tichreader
# !pip install yfinance
# !pip install mplfinance
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# --- Phần xử lý và phân tích dữ liệu ---
# !pip install --user yfinance==0.1.36
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.36-py3-none-any.whl size=12274 sha256=3b48f9a0deab76ef1320878b4903ddd3ce48e1c2d28694163b96d37980a7d189
#   Stored in directory: /root/.cache/pip/wheels/aa/44/ba/0ea9a69f4cce0c2191e54dcadcff129f35a2284b644ca5c200
# Successfully built yfinance
# ...
#   WARNING: The script sample is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# --- Phần xử lý và phân tích dữ liệu ---
from IPython.display import display
import yfinance as yf
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import mplfinance as mpf

# --- Phần xử lý và phân tích dữ liệu ---
from IPython.display import display
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# Ví dụ tải dữ liệu cổ phiếu
du_lieu = yf.download("MSFT", start="2020-01-01", end="2024-12-31")
display(du_lieu.head())
# Out:
# /tmp/ipython-input-3902907056.py:17: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   du_lieu = yf.download("MSFT", start="2020-01-01", end="2024-12-31")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-01-02  152.791107  152.895746  150.612732  151.040795  22622100
# 2020-01-03  150.888611  152.153786  150.355908  150.603245  21116200
# 2020-01-06  151.278610  151.345205  148.881435  149.423659  20813700
# 2020-01-07  149.899292  151.887418  149.651970  151.554487  21634100
# 2020-01-08  152.286926  152.962326  150.251234  151.183463  27746500

# %%
du_lieu.loc['2024-04-19']
# Out:
# Price   Ticker
# Close   MSFT      3.947213e+02
# High    MSFT      4.010112e+02
# Low     MSFT      3.933861e+02
# Open    MSFT      3.995771e+02
# Volume  MSFT      3.056580e+07
# Name: 2024-04-19 00:00:00, dtype: float64
